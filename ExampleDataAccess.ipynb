# %%
from fitbit_helper import FitbitHelper
from datetime import date
from datetime import datetime

from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
# Out:
# /home/amacdon/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # Example data access
# The FitbitHelper object loads the application code and user authorization tokens from the app_config.yaml and user_auth.yaml (discussed in the ApplicationAuthorization notebook) upon creation.

# %%
fbh = FitbitHelper()

# %% [markdown]
# # Heart rate example
# Reads the 1-minute heart rate series, defaulting to today. Start and end dates can be specified to get a different date range. Returns a Pandas Series object (which is immediately plotted in this example).

# %%
fbh.get_heart_rate_series().plot()

# %% [markdown]
# # Sleep data example
# Reads the 1-minute sleep data series, defaulting to today. A different date to read can be specified. Returns a Pandas Series object (which is immediately plotted in this example).

# %%
fbh.get_sleep_series().plot()
